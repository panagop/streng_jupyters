# %%
from streng.ppp.sections.concrete.typical_sections.section_col_rect import ColumnRectangular
from streng.ppp.sections.concrete.reinforcement.combos import LongReinforcementLayer as LongLayer
from streng.tools.rccola import rcmain, rcinput
import matplotlib.pyplot as plt

# %%
cr = ColumnRectangular(b=0.30,
                       h=0.60,
                       cover=0.03,
                       length=4.5,
                       bars_corn_n=2,  # 2 σε κάθε κύρια παρειά
                       bars_corn_dia=0.018,
                       long_layer_main_internal=LongLayer(
                           [2, 0], [0.018, 0.016]),
                       long_layer_sec_internal=LongLayer(
                           [0, 0], [0.018, 0.016]),
                       trans_pattern=3,
                       trans_dia=0.008,
                       trans_s=0.20,
                       rc_in=rcinput,
                       conc_fc = 24.,
                       steel_fy = 440.,
                       steel_Es = 200000.,
                       steel_εsh = 0.01,
                       steel_Esh = 0.,
                       steel_εsu = 0.10,
                       steel_fu = 550.,
                       steel_fy_trans = 440.,
                       steel_εsu_trans = 0.10)

cr.prepare_rccola()

print(cr.rc_in.first_row)
print(cr.rc_in.second_row)
print(cr.rc_in.conc_sect_info)
print(cr.rc_in.reinf_place_info_TYPES12)
print(cr.rc_in.long_reinf_props)
print(cr.rc_in.trans_reinf_info)
print(cr.rc_in.conc_props_ICSTR2348)
# Out:
# PPP =  0.004778500622520124
# PPP2 =  0.004778500622520124
#
#
# *******************************************************
# K = 0    (1 in fortran)
# *******************************************************
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 0  ICOUNT= 1   KCOUNT= 1    ECU=  0.002609
# K= 0  ICOUNT= 1   KCOUNT= 2    ECU=  0.007417
# K= 0  ICOUNT= 1   KCOUNT= 3    ECU=  0.017035
#
# ---------------------------------
# ICOUNT = 2
#
# K= 0  ICOUNT= 2   KCOUNT= 1    ECU=  0.002609
# K= 0  ICOUNT= 2   KCOUNT= 2    ECU=  0.002241
#
# ---------------------------------
# ICOUNT = 3
#
# K= 0  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 0  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 0  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 0  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 0  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 0  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 0  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 0  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 0  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 0  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 0  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 0  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 0  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 0  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 0  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 0  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
#
# ---------------------------------
# ICOUNT = 6
#
# K= 0  ICOUNT= 6   KCOUNT= 1    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 2    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 3    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 4    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 5    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 6    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 7    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 8    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT= 9    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=10    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=11    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=12    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=13    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=14    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=15    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=16    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=17    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=18    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=19    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=20    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=21    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=22    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=23    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=24    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=25    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=26    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=27    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=28    ECU=  0.002000
# K= 0  ICOUNT= 6   KCOUNT=29    ECU=  0.002000
#
# ---------------------------------
# ICOUNT = 7
#
# K= 0  ICOUNT= 7   KCOUNT= 1    ECU=  0.002500
# K= 0  ICOUNT= 7   KCOUNT= 2    ECU=  0.002500
# K= 0  ICOUNT= 7   KCOUNT= 3    ECU=  0.002500
# K= 0  ICOUNT= 7   KCOUNT= 4    ECU=  0.002500
# K= 0  ICOUNT= 7   KCOUNT= 5    ECU=  0.002500
#
# ---------------------------------
# ICOUNT = 8
#
#
# ---------------------------------
# ICOUNT = 9
#
#
# ---------------------------------
# ICOUNT = 10
#
#
# ---------------------------------
# ICOUNT = 11
#
#
# ---------------------------------
# ICOUNT = 12
#
#
# ---------------------------------
# ICOUNT = 13
#
#
# ---------------------------------
# ICOUNT = 14
#
#
# ---------------------------------
# ICOUNT = 15
#
#
# ---------------------------------
# ICOUNT = 16
#
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 0  ICOUNT= 1   KCOUNT= 1    ECU=  0.003014
# K= 0  ICOUNT= 1   KCOUNT= 2    ECU=  0.008227
# K= 0  ICOUNT= 1   KCOUNT= 3    ECU=  0.018655
#
# ---------------------------------
# ICOUNT = 2
#
# K= 0  ICOUNT= 2   KCOUNT= 1    ECU=  0.002300
# K= 0  ICOUNT= 2   KCOUNT= 2    ECU=  0.002211
# K= 0  ICOUNT= 2   KCOUNT= 3    ECU=  0.002208
# K= 0  ICOUNT= 2   KCOUNT= 4    ECU=  0.002207
# K= 0  ICOUNT= 2   KCOUNT= 5    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT= 6    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT= 7    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT= 8    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT= 9    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=10    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=11    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=12    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=13    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=14    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=15    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=16    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=17    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=18    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=19    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=20    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=21    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=22    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=23    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=24    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=25    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=26    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=27    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=28    ECU=  0.002206
# K= 0  ICOUNT= 2   KCOUNT=29    ECU=  0.002206
#
# ---------------------------------
# ICOUNT = 3
#
# K= 0  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 0  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 0  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 0  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 0  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 0  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 0  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 0  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 0  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 0  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 0  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 0  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 0  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 0  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 0  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 0  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 0  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
#
# ---------------------------------
# ICOUNT = 6
#
#
# ---------------------------------
# ICOUNT = 7
#
#
# ---------------------------------
# ICOUNT = 8
#
#
# ---------------------------------
# ICOUNT = 9
#
#
# ---------------------------------
# ICOUNT = 10
#
#
# ---------------------------------
# ICOUNT = 11
#
#
# ---------------------------------
# ICOUNT = 12
#
#
# ---------------------------------
# ICOUNT = 13
#
#
# ---------------------------------
# ICOUNT = 14
#
#
# ---------------------------------
# ICOUNT = 15
#
#
# ---------------------------------
# ICOUNT = 16
#
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
#
# *******************************************************
# K = 1    (2 in fortran)
# *******************************************************
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 1  ICOUNT= 1   KCOUNT= 1    ECU=  0.002609
# K= 1  ICOUNT= 1   KCOUNT= 2    ECU=  0.007417
# K= 1  ICOUNT= 1   KCOUNT= 3    ECU=  0.017035
#
# ---------------------------------
# ICOUNT = 2
#
# K= 1  ICOUNT= 2   KCOUNT= 1    ECU=  0.002609
# K= 1  ICOUNT= 2   KCOUNT= 2    ECU=  0.002241
# K= 1  ICOUNT= 2   KCOUNT= 3    ECU=  0.002275
# K= 1  ICOUNT= 2   KCOUNT= 4    ECU=  0.002327
# K= 1  ICOUNT= 2   KCOUNT= 5    ECU=  0.002394
# K= 1  ICOUNT= 2   KCOUNT= 6    ECU=  0.002353
# K= 1  ICOUNT= 2   KCOUNT= 7    ECU=  0.002339
# K= 1  ICOUNT= 2   KCOUNT= 8    ECU=  0.002346
#
# ---------------------------------
# ICOUNT = 3
#
# K= 1  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 1  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 1  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 1  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 1  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 1  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 1  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 1  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 1  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 1  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 1  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 1  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 1  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 1  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 1  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 1  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
# K= 1  ICOUNT= 5   KCOUNT= 1    ECU=  0.001500
# K= 1  ICOUNT= 5   KCOUNT= 2    ECU=  0.001500
# K= 1  ICOUNT= 5   KCOUNT= 3    ECU=  0.001500
# K= 1  ICOUNT= 5   KCOUNT= 4    ECU=  0.001500
# K= 1  ICOUNT= 5   KCOUNT= 5    ECU=  0.001500
# K= 1  ICOUNT= 5   KCOUNT= 6    ECU=  0.001500
#
# ---------------------------------
# ICOUNT = 6
#
# K= 1  ICOUNT= 6   KCOUNT= 1    ECU=  0.002000
# K= 1  ICOUNT= 6   KCOUNT= 2    ECU=  0.002000
# K= 1  ICOUNT= 6   KCOUNT= 3    ECU=  0.002000
# K= 1  ICOUNT= 6   KCOUNT= 4    ECU=  0.002000
# K= 1  ICOUNT= 6   KCOUNT= 5    ECU=  0.002000
# K= 1  ICOUNT= 6   KCOUNT= 6    ECU=  0.002000
# K= 1  ICOUNT= 6   KCOUNT= 7    ECU=  0.002000
#
# ---------------------------------
# ICOUNT = 7
#
# K= 1  ICOUNT= 7   KCOUNT= 1    ECU=  0.002500
# K= 1  ICOUNT= 7   KCOUNT= 2    ECU=  0.002500
# K= 1  ICOUNT= 7   KCOUNT= 3    ECU=  0.002500
# K= 1  ICOUNT= 7   KCOUNT= 4    ECU=  0.002500
# K= 1  ICOUNT= 7   KCOUNT= 5    ECU=  0.002500
# K= 1  ICOUNT= 7   KCOUNT= 6    ECU=  0.002500
# K= 1  ICOUNT= 7   KCOUNT= 7    ECU=  0.002500
#
# ---------------------------------
# ICOUNT = 8
#
# K= 1  ICOUNT= 8   KCOUNT= 1    ECU=  0.003000
# K= 1  ICOUNT= 8   KCOUNT= 2    ECU=  0.003000
# K= 1  ICOUNT= 8   KCOUNT= 3    ECU=  0.003000
# K= 1  ICOUNT= 8   KCOUNT= 4    ECU=  0.003000
# K= 1  ICOUNT= 8   KCOUNT= 5    ECU=  0.003000
# K= 1  ICOUNT= 8   KCOUNT= 6    ECU=  0.003000
# K= 1  ICOUNT= 8   KCOUNT= 7    ECU=  0.003000
#
# ---------------------------------
# ICOUNT = 9
#
# K= 1  ICOUNT= 9   KCOUNT= 1    ECU=  0.003500
# K= 1  ICOUNT= 9   KCOUNT= 2    ECU=  0.003500
# K= 1  ICOUNT= 9   KCOUNT= 3    ECU=  0.003500
# K= 1  ICOUNT= 9   KCOUNT= 4    ECU=  0.003500
# K= 1  ICOUNT= 9   KCOUNT= 5    ECU=  0.003500
# K= 1  ICOUNT= 9   KCOUNT= 6    ECU=  0.003500
# K= 1  ICOUNT= 9   KCOUNT= 7    ECU=  0.003500
#
# ---------------------------------
# ICOUNT = 10
#
# K= 1  ICOUNT=10   KCOUNT= 1    ECU=  0.004000
# K= 1  ICOUNT=10   KCOUNT= 2    ECU=  0.004000
# K= 1  ICOUNT=10   KCOUNT= 3    ECU=  0.004000
# K= 1  ICOUNT=10   KCOUNT= 4    ECU=  0.004000
# K= 1  ICOUNT=10   KCOUNT= 5    ECU=  0.004000
# K= 1  ICOUNT=10   KCOUNT= 6    ECU=  0.004000
# K= 1  ICOUNT=10   KCOUNT= 7    ECU=  0.004000
# K= 1  ICOUNT=10   KCOUNT= 8    ECU=  0.004000
#
# ---------------------------------
# ICOUNT = 11
#
# K= 1  ICOUNT=11   KCOUNT= 1    ECU=  0.004500
# K= 1  ICOUNT=11   KCOUNT= 2    ECU=  0.004500
# K= 1  ICOUNT=11   KCOUNT= 3    ECU=  0.004500
# K= 1  ICOUNT=11   KCOUNT= 4    ECU=  0.004500
# K= 1  ICOUNT=11   KCOUNT= 5    ECU=  0.004500
# K= 1  ICOUNT=11   KCOUNT= 6    ECU=  0.004500
# K= 1  ICOUNT=11   KCOUNT= 7    ECU=  0.004500
#
# ---------------------------------
# ICOUNT = 12
#
# K= 1  ICOUNT=12   KCOUNT= 1    ECU=  0.005000
#
# ---------------------------------
# ICOUNT = 13
#
#
# ---------------------------------
# ICOUNT = 14
#
#
# ---------------------------------
# ICOUNT = 15
#
#
# ---------------------------------
# ICOUNT = 16
#
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 1  ICOUNT= 1   KCOUNT= 1    ECU=  0.003014
# K= 1  ICOUNT= 1   KCOUNT= 2    ECU=  0.008227
# K= 1  ICOUNT= 1   KCOUNT= 3    ECU=  0.018655
#
# ---------------------------------
# ICOUNT = 2
#
# K= 1  ICOUNT= 2   KCOUNT= 1    ECU=  0.002300
# K= 1  ICOUNT= 2   KCOUNT= 2    ECU=  0.002211
# K= 1  ICOUNT= 2   KCOUNT= 3    ECU=  0.002208
# K= 1  ICOUNT= 2   KCOUNT= 4    ECU=  0.002207
# K= 1  ICOUNT= 2   KCOUNT= 5    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT= 6    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT= 7    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT= 8    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT= 9    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=10    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=11    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=12    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=13    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=14    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=15    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=16    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=17    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=18    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=19    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=20    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=21    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=22    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=23    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=24    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=25    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=26    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=27    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=28    ECU=  0.002206
# K= 1  ICOUNT= 2   KCOUNT=29    ECU=  0.002206
#
# ---------------------------------
# ICOUNT = 3
#
# K= 1  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 1  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 1  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 1  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 1  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 1  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 1  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 1  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 1  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 1  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 1  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 1  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 1  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 1  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 1  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 1  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 1  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
#
# ---------------------------------
# ICOUNT = 6
#
#
# ---------------------------------
# ICOUNT = 7
#
#
# ---------------------------------
# ICOUNT = 8
#
#
# ---------------------------------
# ICOUNT = 9
#
#
# ---------------------------------
# ICOUNT = 10
#
#
# ---------------------------------
# ICOUNT = 11
#
#
# ---------------------------------
# ICOUNT = 12
#
#
# ---------------------------------
# ICOUNT = 13
#
#
# ---------------------------------
# ICOUNT = 14
#
#
# ---------------------------------
# ICOUNT = 15
#
#
# ---------------------------------
# ICOUNT = 16
#
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
#
# *******************************************************
# K = 2    (3 in fortran)
# *******************************************************
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 2  ICOUNT= 1   KCOUNT= 1    ECU=  0.002609
# K= 2  ICOUNT= 1   KCOUNT= 2    ECU=  0.007417
# K= 2  ICOUNT= 1   KCOUNT= 3    ECU=  0.017035
#
# ---------------------------------
# ICOUNT = 2
#
# K= 2  ICOUNT= 2   KCOUNT= 1    ECU=  0.002609
# K= 2  ICOUNT= 2   KCOUNT= 2    ECU=  0.002241
# K= 2  ICOUNT= 2   KCOUNT= 3    ECU=  0.002275
# K= 2  ICOUNT= 2   KCOUNT= 4    ECU=  0.002327
# K= 2  ICOUNT= 2   KCOUNT= 5    ECU=  0.002394
# K= 2  ICOUNT= 2   KCOUNT= 6    ECU=  0.002463
# K= 2  ICOUNT= 2   KCOUNT= 7    ECU=  0.002423
# K= 2  ICOUNT= 2   KCOUNT= 8    ECU=  0.002407
# K= 2  ICOUNT= 2   KCOUNT= 9    ECU=  0.002415
#
# ---------------------------------
# ICOUNT = 3
#
# K= 2  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 2  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 2  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 2  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 2  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 2  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 2  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 2  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 2  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 2  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 2  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 2  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 2  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 2  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 2  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 2  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
# K= 2  ICOUNT= 5   KCOUNT= 1    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 2    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 3    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 4    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 5    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 6    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 7    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 8    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 9    ECU=  0.001500
#
# ---------------------------------
# ICOUNT = 6
#
# K= 2  ICOUNT= 6   KCOUNT= 1    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 2    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 3    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 4    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 5    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 6    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 7    ECU=  0.002000
#
# ---------------------------------
# ICOUNT = 7
#
# K= 2  ICOUNT= 7   KCOUNT= 1    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 2    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 3    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 4    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 5    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 6    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 7    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 8    ECU=  0.002500
#
# ---------------------------------
# ICOUNT = 8
#
# K= 2  ICOUNT= 8   KCOUNT= 1    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 2    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 3    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 4    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 5    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 6    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 7    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 8    ECU=  0.003000
#
# ---------------------------------
# ICOUNT = 9
#
# K= 2  ICOUNT= 9   KCOUNT= 1    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 2    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 3    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 4    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 5    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 6    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 7    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 8    ECU=  0.003500
#
# ---------------------------------
# ICOUNT = 10
#
# K= 2  ICOUNT=10   KCOUNT= 1    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 2    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 3    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 4    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 5    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 6    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 7    ECU=  0.004000
#
# ---------------------------------
# ICOUNT = 11
#
# K= 2  ICOUNT=11   KCOUNT= 1    ECU=  0.004500
#
# ---------------------------------
# ICOUNT = 12
#
# K= 2  ICOUNT=12   KCOUNT= 1    ECU=  0.005000
#
# ---------------------------------
# ICOUNT = 13
#
# K= 2  ICOUNT=13   KCOUNT= 1    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 2    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 3    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 4    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 5    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 6    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 7    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 8    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT= 9    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT=10    ECU=  0.006000
# K= 2  ICOUNT=13   KCOUNT=11    ECU=  0.006000
#
# ---------------------------------
# ICOUNT = 14
#
# K= 2  ICOUNT=14   KCOUNT= 1    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 2    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 3    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 4    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 5    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 6    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 7    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 8    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT= 9    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT=10    ECU=  0.007000
# K= 2  ICOUNT=14   KCOUNT=11    ECU=  0.007000
#
# ---------------------------------
# ICOUNT = 15
#
# K= 2  ICOUNT=15   KCOUNT= 1    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 2    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 3    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 4    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 5    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 6    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 7    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 8    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT= 9    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT=10    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT=11    ECU=  0.008000
# K= 2  ICOUNT=15   KCOUNT=12    ECU=  0.008000
#
# ---------------------------------
# ICOUNT = 16
#
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 2  ICOUNT= 1   KCOUNT= 1    ECU=  0.003014
# K= 2  ICOUNT= 1   KCOUNT= 2    ECU=  0.008227
# K= 2  ICOUNT= 1   KCOUNT= 3    ECU=  0.018655
#
# ---------------------------------
# ICOUNT = 2
#
# K= 2  ICOUNT= 2   KCOUNT= 1    ECU=  0.002300
# K= 2  ICOUNT= 2   KCOUNT= 2    ECU=  0.002211
# K= 2  ICOUNT= 2   KCOUNT= 3    ECU=  0.002220
# K= 2  ICOUNT= 2   KCOUNT= 4    ECU=  0.002234
# K= 2  ICOUNT= 2   KCOUNT= 5    ECU=  0.002250
# K= 2  ICOUNT= 2   KCOUNT= 6    ECU=  0.002240
# K= 2  ICOUNT= 2   KCOUNT= 7    ECU=  0.002237
# K= 2  ICOUNT= 2   KCOUNT= 8    ECU=  0.002238
#
# ---------------------------------
# ICOUNT = 3
#
# K= 2  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 2  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 2  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 2  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 2  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 2  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 2  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 2  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 2  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 2  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 2  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 2  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 2  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 2  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 2  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 2  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 2  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
# K= 2  ICOUNT= 5   KCOUNT= 1    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 2    ECU=  0.001500
# K= 2  ICOUNT= 5   KCOUNT= 3    ECU=  0.001500
#
# ---------------------------------
# ICOUNT = 6
#
# K= 2  ICOUNT= 6   KCOUNT= 1    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 2    ECU=  0.002000
# K= 2  ICOUNT= 6   KCOUNT= 3    ECU=  0.002000
#
# ---------------------------------
# ICOUNT = 7
#
# K= 2  ICOUNT= 7   KCOUNT= 1    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 2    ECU=  0.002500
# K= 2  ICOUNT= 7   KCOUNT= 3    ECU=  0.002500
#
# ---------------------------------
# ICOUNT = 8
#
# K= 2  ICOUNT= 8   KCOUNT= 1    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 2    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 3    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 4    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 5    ECU=  0.003000
# K= 2  ICOUNT= 8   KCOUNT= 6    ECU=  0.003000
#
# ---------------------------------
# ICOUNT = 9
#
# K= 2  ICOUNT= 9   KCOUNT= 1    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 2    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 3    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 4    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 5    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 6    ECU=  0.003500
# K= 2  ICOUNT= 9   KCOUNT= 7    ECU=  0.003500
#
# ---------------------------------
# ICOUNT = 10
#
# K= 2  ICOUNT=10   KCOUNT= 1    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 2    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 3    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 4    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 5    ECU=  0.004000
# K= 2  ICOUNT=10   KCOUNT= 6    ECU=  0.004000
#
# ---------------------------------
# ICOUNT = 11
#
# K= 2  ICOUNT=11   KCOUNT= 1    ECU=  0.004500
# K= 2  ICOUNT=11   KCOUNT= 2    ECU=  0.004500
# K= 2  ICOUNT=11   KCOUNT= 3    ECU=  0.004500
# K= 2  ICOUNT=11   KCOUNT= 4    ECU=  0.004500
# K= 2  ICOUNT=11   KCOUNT= 5    ECU=  0.004500
# K= 2  ICOUNT=11   KCOUNT= 6    ECU=  0.004500
# K= 2  ICOUNT=11   KCOUNT= 7    ECU=  0.004500
# K= 2  ICOUNT=11   KCOUNT= 8    ECU=  0.004500
#
# ---------------------------------
# ICOUNT = 12
#
# K= 2  ICOUNT=12   KCOUNT= 1    ECU=  0.005000
# K= 2  ICOUNT=12   KCOUNT= 2    ECU=  0.005000
# K= 2  ICOUNT=12   KCOUNT= 3    ECU=  0.005000
# K= 2  ICOUNT=12   KCOUNT= 4    ECU=  0.005000
# K= 2  ICOUNT=12   KCOUNT= 5    ECU=  0.005000
# K= 2  ICOUNT=12   KCOUNT= 6    ECU=  0.005000
# K= 2  ICOUNT=12   KCOUNT= 7    ECU=  0.005000
# K= 2  ICOUNT=12   KCOUNT= 8    ECU=  0.005000
#
# ---------------------------------
# ICOUNT = 13
#
#
# ---------------------------------
# ICOUNT = 14
#
#
# ---------------------------------
# ICOUNT = 15
#
#
# ---------------------------------
# ICOUNT = 16
#
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
#
# *******************************************************
# K = 3    (4 in fortran)
# *******************************************************
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 3  ICOUNT= 1   KCOUNT= 1    ECU=  0.002609
# K= 3  ICOUNT= 1   KCOUNT= 2    ECU=  0.007417
# K= 3  ICOUNT= 1   KCOUNT= 3    ECU=  0.017035
#
# ---------------------------------
# ICOUNT = 2
#
# K= 3  ICOUNT= 2   KCOUNT= 1    ECU=  0.002609
# K= 3  ICOUNT= 2   KCOUNT= 2    ECU=  0.002241
# K= 3  ICOUNT= 2   KCOUNT= 3    ECU=  0.002275
# K= 3  ICOUNT= 2   KCOUNT= 4    ECU=  0.002327
# K= 3  ICOUNT= 2   KCOUNT= 5    ECU=  0.002394
# K= 3  ICOUNT= 2   KCOUNT= 6    ECU=  0.002463
# K= 3  ICOUNT= 2   KCOUNT= 7    ECU=  0.002423
# K= 3  ICOUNT= 2   KCOUNT= 8    ECU=  0.002441
# K= 3  ICOUNT= 2   KCOUNT= 9    ECU=  0.002451
# K= 3  ICOUNT= 2   KCOUNT=10    ECU=  0.002457
# K= 3  ICOUNT= 2   KCOUNT=11    ECU=  0.002460
#
# ---------------------------------
# ICOUNT = 3
#
# K= 3  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 3  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 3  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 3  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 3  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 3  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 3  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 3  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 3  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 3  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 3  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 3  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 3  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 3  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 3  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 3  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
# K= 3  ICOUNT= 5   KCOUNT= 1    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 2    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 3    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 4    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 5    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 6    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 7    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 8    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 9    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT=10    ECU=  0.001500
#
# ---------------------------------
# ICOUNT = 6
#
# K= 3  ICOUNT= 6   KCOUNT= 1    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 2    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 3    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 4    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 5    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 6    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 7    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 8    ECU=  0.002000
#
# ---------------------------------
# ICOUNT = 7
#
# K= 3  ICOUNT= 7   KCOUNT= 1    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 2    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 3    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 4    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 5    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 6    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 7    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 8    ECU=  0.002500
#
# ---------------------------------
# ICOUNT = 8
#
# K= 3  ICOUNT= 8   KCOUNT= 1    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 2    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 3    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 4    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 5    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 6    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 7    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 8    ECU=  0.003000
#
# ---------------------------------
# ICOUNT = 9
#
# K= 3  ICOUNT= 9   KCOUNT= 1    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 2    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 3    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 4    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 5    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 6    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 7    ECU=  0.003500
#
# ---------------------------------
# ICOUNT = 10
#
# K= 3  ICOUNT=10   KCOUNT= 1    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 2    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 3    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 4    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 5    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 6    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 7    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 8    ECU=  0.004000
#
# ---------------------------------
# ICOUNT = 11
#
# K= 3  ICOUNT=11   KCOUNT= 1    ECU=  0.004500
#
# ---------------------------------
# ICOUNT = 12
#
# K= 3  ICOUNT=12   KCOUNT= 1    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 2    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 3    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 4    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 5    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 6    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 7    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 8    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT= 9    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT=10    ECU=  0.005000
# K= 3  ICOUNT=12   KCOUNT=11    ECU=  0.005000
#
# ---------------------------------
# ICOUNT = 13
#
# K= 3  ICOUNT=13   KCOUNT= 1    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 2    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 3    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 4    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 5    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 6    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 7    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 8    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 9    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT=10    ECU=  0.006000
#
# ---------------------------------
# ICOUNT = 14
#
# K= 3  ICOUNT=14   KCOUNT= 1    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 2    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 3    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 4    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 5    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 6    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 7    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 8    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 9    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT=10    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT=11    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT=12    ECU=  0.007000
#
# ---------------------------------
# ICOUNT = 15
#
# K= 3  ICOUNT=15   KCOUNT= 1    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 2    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 3    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 4    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 5    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 6    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 7    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 8    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT= 9    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT=10    ECU=  0.008000
# K= 3  ICOUNT=15   KCOUNT=11    ECU=  0.008000
#
# ---------------------------------
# ICOUNT = 16
#
# K= 3  ICOUNT=16   KCOUNT= 1    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 2    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 3    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 4    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 5    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 6    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 7    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 8    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT= 9    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT=10    ECU=  0.009000
# K= 3  ICOUNT=16   KCOUNT=11    ECU=  0.009000
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 3  ICOUNT= 1   KCOUNT= 1    ECU=  0.003014
# K= 3  ICOUNT= 1   KCOUNT= 2    ECU=  0.008227
# K= 3  ICOUNT= 1   KCOUNT= 3    ECU=  0.018655
#
# ---------------------------------
# ICOUNT = 2
#
# K= 3  ICOUNT= 2   KCOUNT= 1    ECU=  0.002300
# K= 3  ICOUNT= 2   KCOUNT= 2    ECU=  0.002211
# K= 3  ICOUNT= 2   KCOUNT= 3    ECU=  0.002220
# K= 3  ICOUNT= 2   KCOUNT= 4    ECU=  0.002234
# K= 3  ICOUNT= 2   KCOUNT= 5    ECU=  0.002250
# K= 3  ICOUNT= 2   KCOUNT= 6    ECU=  0.002267
# K= 3  ICOUNT= 2   KCOUNT= 7    ECU=  0.002257
# K= 3  ICOUNT= 2   KCOUNT= 8    ECU=  0.002254
# K= 3  ICOUNT= 2   KCOUNT= 9    ECU=  0.002252
#
# ---------------------------------
# ICOUNT = 3
#
# K= 3  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 3  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 3  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 3  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 3  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 3  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 3  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 3  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 3  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 3  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 3  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 3  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 3  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 3  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 3  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 3  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 3  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
# K= 3  ICOUNT= 5   KCOUNT= 1    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 2    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 3    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 4    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 5    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 6    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 7    ECU=  0.001500
# K= 3  ICOUNT= 5   KCOUNT= 8    ECU=  0.001500
#
# ---------------------------------
# ICOUNT = 6
#
# K= 3  ICOUNT= 6   KCOUNT= 1    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 2    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 3    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 4    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 5    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 6    ECU=  0.002000
# K= 3  ICOUNT= 6   KCOUNT= 7    ECU=  0.002000
#
# ---------------------------------
# ICOUNT = 7
#
# K= 3  ICOUNT= 7   KCOUNT= 1    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 2    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 3    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 4    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 5    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 6    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 7    ECU=  0.002500
# K= 3  ICOUNT= 7   KCOUNT= 8    ECU=  0.002500
#
# ---------------------------------
# ICOUNT = 8
#
# K= 3  ICOUNT= 8   KCOUNT= 1    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 2    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 3    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 4    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 5    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 6    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 7    ECU=  0.003000
# K= 3  ICOUNT= 8   KCOUNT= 8    ECU=  0.003000
#
# ---------------------------------
# ICOUNT = 9
#
# K= 3  ICOUNT= 9   KCOUNT= 1    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 2    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 3    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 4    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 5    ECU=  0.003500
# K= 3  ICOUNT= 9   KCOUNT= 6    ECU=  0.003500
#
# ---------------------------------
# ICOUNT = 10
#
# K= 3  ICOUNT=10   KCOUNT= 1    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 2    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 3    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 4    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 5    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 6    ECU=  0.004000
# K= 3  ICOUNT=10   KCOUNT= 7    ECU=  0.004000
#
# ---------------------------------
# ICOUNT = 11
#
# K= 3  ICOUNT=11   KCOUNT= 1    ECU=  0.004500
#
# ---------------------------------
# ICOUNT = 12
#
# K= 3  ICOUNT=12   KCOUNT= 1    ECU=  0.005000
#
# ---------------------------------
# ICOUNT = 13
#
# K= 3  ICOUNT=13   KCOUNT= 1    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 2    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 3    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 4    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 5    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 6    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 7    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 8    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT= 9    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT=10    ECU=  0.006000
# K= 3  ICOUNT=13   KCOUNT=11    ECU=  0.006000
#
# ---------------------------------
# ICOUNT = 14
#
# K= 3  ICOUNT=14   KCOUNT= 1    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 2    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 3    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 4    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 5    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 6    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 7    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 8    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT= 9    ECU=  0.007000
# K= 3  ICOUNT=14   KCOUNT=10    ECU=  0.007000
#
# ---------------------------------
# ICOUNT = 15
#
#
# ---------------------------------
# ICOUNT = 16
#
#
# ---------------------------------
# ICOUNT = 17
#
#
# ---------------------------------
# ICOUNT = 18
#
#
# ---------------------------------
# ICOUNT = 19
#
#
# ---------------------------------
# ICOUNT = 20
#
#
# ---------------------------------
# ICOUNT = 21
#
#
# ---------------------------------
# ICOUNT = 22
#
#
# ---------------------------------
# ICOUNT = 23
#
#
# ---------------------------------
# ICOUNT = 24
#
#
# ---------------------------------
# ICOUNT = 25
#
#
# ---------------------------------
# ICOUNT = 26
#
#
# ---------------------------------
# ICOUNT = 27
#
#
#
# *******************************************************
# K = 4    (5 in fortran)
# *******************************************************
#
#
# ---------------------------------
# ICOUNT = 1
#
# K= 4  ICOUNT= 1   KCOUNT= 1    ECU=  0.002609
# K= 4  ICOUNT= 1   KCOUNT= 2    ECU=  0.007417
# K= 4  ICOUNT= 1   KCOUNT= 3    ECU=  0.004212
# K= 4  ICOUNT= 1   KCOUNT= 4    ECU=  0.003296
# K= 4  ICOUNT= 1   KCOUNT= 5    ECU=  0.003718
# K= 4  ICOUNT= 1   KCOUNT= 6    ECU=  0.003955
#
# ---------------------------------
# ICOUNT = 2
#
# K= 4  ICOUNT= 2   KCOUNT= 1    ECU=  0.002609
# K= 4  ICOUNT= 2   KCOUNT= 2    ECU=  0.002241
# K= 4  ICOUNT= 2   KCOUNT= 3    ECU=  0.002275
# K= 4  ICOUNT= 2   KCOUNT= 4    ECU=  0.002327
# K= 4  ICOUNT= 2   KCOUNT= 5    ECU=  0.002394
# K= 4  ICOUNT= 2   KCOUNT= 6    ECU=  0.002463
# K= 4  ICOUNT= 2   KCOUNT= 7    ECU=  0.002520
# K= 4  ICOUNT= 2   KCOUNT= 8    ECU=  0.002559
# K= 4  ICOUNT= 2   KCOUNT= 9    ECU=  0.002538
# K= 4  ICOUNT= 2   KCOUNT=10    ECU=  0.002529
# K= 4  ICOUNT= 2   KCOUNT=11    ECU=  0.002524
#
# ---------------------------------
# ICOUNT = 3
#
# K= 4  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K= 4  ICOUNT= 3   KCOUNT= 2    ECU=  0.011036
# K= 4  ICOUNT= 3   KCOUNT= 3    ECU=  0.013117
# K= 4  ICOUNT= 3   KCOUNT= 4    ECU=  0.014187
# K= 4  ICOUNT= 3   KCOUNT= 5    ECU=  0.014729
# K= 4  ICOUNT= 3   KCOUNT= 6    ECU=  0.015002
# K= 4  ICOUNT= 3   KCOUNT= 7    ECU=  0.015139
# K= 4  ICOUNT= 3   KCOUNT= 8    ECU=  0.015208
# K= 4  ICOUNT= 3   KCOUNT= 9    ECU=  0.015243
# K= 4  ICOUNT= 3   KCOUNT=10    ECU=  0.015260
# K= 4  ICOUNT= 3   KCOUNT=11    ECU=  0.015268
# K= 4  ICOUNT= 3   KCOUNT=12    ECU=  0.015273
# K= 4  ICOUNT= 3   KCOUNT=13    ECU=  0.015275
# K= 4  ICOUNT= 3   KCOUNT=14    ECU=  0.015276
# K= 4  ICOUNT= 3   KCOUNT=15    ECU=  0.015276
# K= 4  ICOUNT= 3   KCOUNT=16    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=17    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=18    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=19    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=20    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=21    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=22    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=23    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=24    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=25    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=26    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=27    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=28    ECU=  0.015277
# K= 4  ICOUNT= 3   KCOUNT=29    ECU=  0.015277
#
# ---------------------------------
# ICOUNT = 4
#
#
# ---------------------------------
# ICOUNT = 5
#
# K= 4  ICOUNT= 5   KCOUNT= 1    ECU=  0.001500
# K= 4  ICOUNT= 5   KCOUNT= 2    ECU=  0.001500
# K= 4  ICOUNT= 5   KCOUNT= 3    ECU=  0.001500
# K= 4  ICOUNT= 5   KCOUNT= 4    ECU=  0.001500
# K= 4  ICOUNT= 5   KCOUNT= 5    ECU=  0.001500
# K= 4  ICOUNT= 5   KCOUNT= 6    ECU=  0.001500
# K= 4  ICOUNT= 5   KCOUNT= 7    ECU=  0.001500
# K= 4  ICOUNT= 5   KCOUNT= 8    ECU=  0.001500
# ...
# ICOUNT = 24
#
# K=14  ICOUNT=24   KCOUNT= 1    ECU=  0.045000
#
# ---------------------------------
# ICOUNT = 25
#
# K=14  ICOUNT=25   KCOUNT= 1    ECU=  0.050000
#
# ---------------------------------
# ICOUNT = 26
#
# K=14  ICOUNT=26   KCOUNT= 1    ECU=  0.060000
#
# ---------------------------------
# ICOUNT = 27
#
# K=14  ICOUNT=27   KCOUNT= 1    ECU=  0.070000
#
# ---------------------------------
# ICOUNT = 1
#
# K=14  ICOUNT= 1   KCOUNT= 1    ECU=  0.003014
# K=14  ICOUNT= 1   KCOUNT= 2    ECU=  0.000894
# K=14  ICOUNT= 1   KCOUNT= 3    ECU=  0.000372
# K=14  ICOUNT= 1   KCOUNT= 4    ECU=  0.000171
# K=14  ICOUNT= 1   KCOUNT= 5    ECU=  0.000082
# K=14  ICOUNT= 1   KCOUNT= 6    ECU=  0.000040
# K=14  ICOUNT= 1   KCOUNT= 7    ECU=  0.000020
# K=14  ICOUNT= 1   KCOUNT= 8    ECU=  0.000010
# K=14  ICOUNT= 1   KCOUNT= 9    ECU=  0.000005
# K=14  ICOUNT= 1   KCOUNT=10    ECU=  0.000002
# K=14  ICOUNT= 1   KCOUNT=11    ECU=  0.000001
# K=14  ICOUNT= 1   KCOUNT=12    ECU=  0.000001
# K=14  ICOUNT= 1   KCOUNT=13    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=14    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=15    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=16    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=17    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=18    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=19    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=20    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=21    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=22    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=23    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=24    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=25    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=26    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=27    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=28    ECU=  0.000000
# K=14  ICOUNT= 1   KCOUNT=29    ECU=  0.000000
#
# ---------------------------------
# ICOUNT = 2
#
# K=14  ICOUNT= 2   KCOUNT= 1    ECU=  0.002300
# K=14  ICOUNT= 2   KCOUNT= 2    ECU=  0.002399
# K=14  ICOUNT= 2   KCOUNT= 3    ECU=  0.002599
# K=14  ICOUNT= 2   KCOUNT= 4    ECU=  0.002997
# K=14  ICOUNT= 2   KCOUNT= 5    ECU=  0.003794
# K=14  ICOUNT= 2   KCOUNT= 6    ECU=  0.005389
# K=14  ICOUNT= 2   KCOUNT= 7    ECU=  0.008578
# K=14  ICOUNT= 2   KCOUNT= 8    ECU=  0.014955
# K=14  ICOUNT= 2   KCOUNT= 9    ECU=  0.027711
#
# ---------------------------------
# ICOUNT = 3
#
# K=14  ICOUNT= 3   KCOUNT= 1    ECU=  0.007096
# K=14  ICOUNT= 3   KCOUNT= 2    ECU=  0.003427
# K=14  ICOUNT= 3   KCOUNT= 3    ECU=  0.001684
# K=14  ICOUNT= 3   KCOUNT= 4    ECU=  0.000835
#
# ---------------------------------
# ICOUNT = 4
#
# K=14  ICOUNT= 4   KCOUNT= 1    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 2    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 3    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 4    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 5    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 6    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 7    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 8    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT= 9    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT=10    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT=11    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT=12    ECU=  0.000500
# K=14  ICOUNT= 4   KCOUNT=13    ECU=  0.000500
#
# ---------------------------------
# ICOUNT = 5
#
# K=14  ICOUNT= 5   KCOUNT= 1    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 2    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 3    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 4    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 5    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 6    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 7    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 8    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT= 9    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=10    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=11    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=12    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=13    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=14    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=15    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=16    ECU=  0.001500
# K=14  ICOUNT= 5   KCOUNT=17    ECU=  0.001500
#
# ---------------------------------
# ICOUNT = 6
#
# K=14  ICOUNT= 6   KCOUNT= 1    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 2    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 3    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 4    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 5    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 6    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 7    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 8    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT= 9    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT=10    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT=11    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT=12    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT=13    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT=14    ECU=  0.002000
# K=14  ICOUNT= 6   KCOUNT=15    ECU=  0.002000
#
# ---------------------------------
# ICOUNT = 7
#
# K=14  ICOUNT= 7   KCOUNT= 1    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 2    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 3    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 4    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 5    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 6    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 7    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 8    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT= 9    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=10    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=11    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=12    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=13    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=14    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=15    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=16    ECU=  0.002500
# K=14  ICOUNT= 7   KCOUNT=17    ECU=  0.002500
#
# ---------------------------------
# ICOUNT = 8
#
# K=14  ICOUNT= 8   KCOUNT= 1    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 2    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 3    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 4    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 5    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 6    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 7    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 8    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT= 9    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=10    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=11    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=12    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=13    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=14    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=15    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=16    ECU=  0.003000
# K=14  ICOUNT= 8   KCOUNT=17    ECU=  0.003000
#
# ---------------------------------
# ICOUNT = 9
#
# K=14  ICOUNT= 9   KCOUNT= 1    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 2    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 3    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 4    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 5    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 6    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 7    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 8    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT= 9    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT=10    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT=11    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT=12    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT=13    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT=14    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT=15    ECU=  0.003500
# K=14  ICOUNT= 9   KCOUNT=16    ECU=  0.003500
#
# ---------------------------------
# ICOUNT = 10
#
# K=14  ICOUNT=10   KCOUNT= 1    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 2    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 3    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 4    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 5    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 6    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 7    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 8    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT= 9    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=10    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=11    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=12    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=13    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=14    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=15    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=16    ECU=  0.004000
# K=14  ICOUNT=10   KCOUNT=17    ECU=  0.004000
#
# ---------------------------------
# ICOUNT = 11
#
# K=14  ICOUNT=11   KCOUNT= 1    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 2    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 3    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 4    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 5    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 6    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 7    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 8    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT= 9    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=10    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=11    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=12    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=13    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=14    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=15    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=16    ECU=  0.004500
# K=14  ICOUNT=11   KCOUNT=17    ECU=  0.004500
#
# ---------------------------------
# ICOUNT = 12
#
# K=14  ICOUNT=12   KCOUNT= 1    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 2    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 3    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 4    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 5    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 6    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 7    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 8    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT= 9    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=10    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=11    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=12    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=13    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=14    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=15    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=16    ECU=  0.005000
# K=14  ICOUNT=12   KCOUNT=17    ECU=  0.005000
#
# ---------------------------------
# ICOUNT = 13
#
# K=14  ICOUNT=13   KCOUNT= 1    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 2    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 3    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 4    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 5    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 6    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 7    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 8    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT= 9    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT=10    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT=11    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT=12    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT=13    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT=14    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT=15    ECU=  0.006000
# K=14  ICOUNT=13   KCOUNT=16    ECU=  0.006000
#
# ---------------------------------
# ICOUNT = 14
#
# K=14  ICOUNT=14   KCOUNT= 1    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 2    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 3    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 4    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 5    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 6    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 7    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 8    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT= 9    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=10    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=11    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=12    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=13    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=14    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=15    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=16    ECU=  0.007000
# K=14  ICOUNT=14   KCOUNT=17    ECU=  0.007000
#
# ---------------------------------
# ICOUNT = 15
#
# K=14  ICOUNT=15   KCOUNT= 1    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 2    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 3    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 4    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 5    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 6    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 7    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 8    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT= 9    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT=10    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT=11    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT=12    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT=13    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT=14    ECU=  0.008000
# K=14  ICOUNT=15   KCOUNT=15    ECU=  0.008000
#
# ---------------------------------
# ICOUNT = 16
#
# K=14  ICOUNT=16   KCOUNT= 1    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 2    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 3    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 4    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 5    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 6    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 7    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 8    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT= 9    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=10    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=11    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=12    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=13    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=14    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=15    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=16    ECU=  0.009000
# K=14  ICOUNT=16   KCOUNT=17    ECU=  0.009000
#
# ---------------------------------
# ICOUNT = 17
#
# K=14  ICOUNT=17   KCOUNT= 1    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 2    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 3    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 4    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 5    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 6    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 7    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 8    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT= 9    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=10    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=11    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=12    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=13    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=14    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=15    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=16    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=17    ECU=  0.010000
# K=14  ICOUNT=17   KCOUNT=18    ECU=  0.010000
#
# ---------------------------------
# ICOUNT = 18
#
# K=14  ICOUNT=18   KCOUNT= 1    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 2    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 3    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 4    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 5    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 6    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 7    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 8    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT= 9    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=10    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=11    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=12    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=13    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=14    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=15    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=16    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=17    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=18    ECU=  0.015000
# K=14  ICOUNT=18   KCOUNT=19    ECU=  0.015000
#
# ---------------------------------
# ICOUNT = 19
#
# K=14  ICOUNT=19   KCOUNT= 1    ECU=  0.020000
#
# ---------------------------------
# ICOUNT = 20
#
# K=14  ICOUNT=20   KCOUNT= 1    ECU=  0.025000
#
# ---------------------------------
# ICOUNT = 21
#
# K=14  ICOUNT=21   KCOUNT= 1    ECU=  0.030000
#
# ---------------------------------
# ICOUNT = 22
#
# K=14  ICOUNT=22   KCOUNT= 1    ECU=  0.035000
#
# ---------------------------------
# ICOUNT = 23
#
# K=14  ICOUNT=23   KCOUNT= 1    ECU=  0.040000
#
# ---------------------------------
# ICOUNT = 24
#
# K=14  ICOUNT=24   KCOUNT= 1    ECU=  0.045000
#
# ---------------------------------
# ICOUNT = 25
#
# K=14  ICOUNT=25   KCOUNT= 1    ECU=  0.050000
#
# ---------------------------------
# ICOUNT = 26
#
# K=14  ICOUNT=26   KCOUNT= 1    ECU=  0.060000
#
# ---------------------------------
# ICOUNT = 27
#
# K=14  ICOUNT=27   KCOUNT= 1    ECU=  0.070000
# FirstRow(TYPEC=1, TYPES=1, ISPALL=0, ICSTR=8, ICSTRS=0, NPTS=0, NPTSS=0, ITCONF=1, ISSTL=0, IECU=1, ISSTR=0, IGRAPH=3)
# SecondRow(NLOAD=0, NLAYER=0, NDATA1=0, NDATA2=0, NSTRNI=24, NSTRNC=24, NITT=30)
# ConcSectInfo(T=0.6, B=0.3, TC=0.532, BC=0.23199999999999998)
# ReinfPlaceInfoTYPES12(GT=0.506, NB1=8, AS1=2.5446900494077322, NB2=0, AS2=0.0, NBAR=1, AF=None)
# LongReinfProps(FYS=440.0, YMS=200000.0, ESH=0.01, YSH=0.0, ESU=0.1, FSU=550.0, ESDYN=None)
# TransReinfInfo(FYSTRP=440.0, ASSTRP=1.0053096491487337, S=0.2, XL=4.5, XSTRP=2.0, ESUSTRP=0.1)
# ConcPropsICSTR2348(FCJ=24.0, S=0.2, PPP=0.004778500622520124)

# %%
cr.rcc.uniaxial_bending_ini_dfs[11]
# Out:
#      K   i        εc    N         M      M/My         φ       Duct        εs  \
# 0   12   A  0.000801  0.0  0.224879  0.000000  0.005427   0.000000 -0.002200
# 1   12   B  0.000000  0.0  0.000000  0.000000  0.000000   0.000000  0.000000
# 2   12   C  0.010909  0.0  0.287523  1.278568  0.200558  36.952275 -0.100000
# 3   12   1  0.000500  0.0  0.143526  0.638237  0.003441   0.633969 -0.001403
# 4   12   2  0.001500  0.0  0.232702  1.034787  0.017855   3.289784 -0.008374
# 5   12   3  0.002000  0.0  0.240126  1.067798  0.028216   5.198670 -0.013603
# 6   12   4  0.002500  0.0  0.249638  1.110099  0.038259   7.049045 -0.018657
# 7   12   5  0.003000  0.0  0.256840  1.142126  0.048168   8.874863 -0.023637
# 8   12   6  0.003500  0.0  0.262333  1.166549  0.058009  10.688007 -0.028579
# 9   12   7  0.004000  0.0  0.268210  1.192682  0.067348  12.408752 -0.033244
# 10  12   8  0.004500  0.0  0.272161  1.210252  0.076970  14.181430 -0.038064
# 11  12   9  0.005000  0.0  0.276603  1.230006  0.086195  15.881217 -0.042666
# 12  12  10  0.006000  0.0  0.282497  1.256214  0.105076  19.359960 -0.052107
# 13  12  11  0.007000  0.0  0.285080  1.267702  0.124535  22.945137 -0.061868
# 14  12  12  0.008000  0.0  0.288104  1.281152  0.143446  26.429495 -0.071326
# 15  12  13  0.009000  0.0  0.289489  1.287309  0.162647  29.967301 -0.080944
# 16  12  14  0.010000  0.0  0.287601  1.278912  0.182862  33.691827 -0.091123
# 17  12  15  0.015000  0.0  0.286157  1.272491  0.282004  51.958480 -0.140948
#
#            x         V      M(V)
# 0   0.147656  0.257163  0.578617
# 1   0.000000  0.000000  0.000000
# 2   0.054392  0.257133  0.578549
# 3   0.145313  0.257133  0.578549
# 4   0.084009  0.257133  0.578549
# 5   0.070882  0.257133  0.578549
# 6   0.065345  0.257133  0.578549
# 7   0.062282  0.257133  0.578549
# 8   0.060335  0.257133  0.578549
# 9   0.059393  0.257133  0.578549
# 10  0.058465  0.257133  0.578549
# 11  0.058008  0.257133  0.578549
# 12  0.057102  0.257133  0.578549
# 13  0.056209  0.257133  0.578549
# 14  0.055770  0.257133  0.578549
# 15  0.055334  0.257133  0.578549
# 16  0.054686  0.257133  0.578549
# 17  0.053191  0.257133  0.578549

# %%
cr.rcc.uniaxial_bending_conf_dfs[11]
# Out:
#      K   i        εc    N         M      M/My         φ       Duct   εs  \
# 0   12   A  0.000894  0.0  0.215539  0.958466  0.005962   1.098493  0.0
# 1   12   B  0.004022  0.0  0.281274  1.250777  0.140169  25.825784  0.0
# 2   12   C  0.005922  0.0  0.283290  1.259744  0.204088  37.602722  0.0
# 3   12   1  0.000500  0.0  0.123559  0.549444  0.003386   0.623906  0.0
# 4   12   2  0.001500  0.0  0.223305  0.992998  0.020973   3.864190  0.0
# 5   12   3  0.002000  0.0  0.239253  1.063917  0.038078   7.015835  0.0
# 6   12   4  0.002500  0.0  0.254459  1.131538  0.058582  10.793592  0.0
# 7   12   5  0.003000  0.0  0.265701  1.181527  0.083317  15.350887  0.0
# 8   12   6  0.003500  0.0  0.275468  1.224958  0.109140  20.108764  0.0
# 9   12   7  0.004000  0.0  0.281513  1.251842  0.137635  25.358835  0.0
# 10  12   8  0.004500  0.0  0.282637  1.256838  0.154839  28.528689  0.0
# 11  12   9  0.005000  0.0  0.283241  1.259523  0.172044  31.698544  0.0
# 12  12  10  0.006000  0.0  0.283321  1.259879  0.206452  38.038252  0.0
# 13  12  11  0.007000  0.0  0.282823  1.257664  0.240861  44.377961  0.0
# 14  12  12  0.008000  0.0  0.282063  1.254285  0.275270  50.717670  0.0
# 15  12  13  0.009000  0.0  0.283652  1.261352  0.286698  52.823220  0.0
# 16  12  14  0.010000  0.0  0.282508  1.256264  0.318553  58.692466  0.0
# 17  12  15  0.015000  0.0  0.281262  1.250723  0.416103  76.665716  0.0
#
#            x         V      M(V)
# 0   0.150000  0.208641  0.469443
# 1   0.028695  0.208641  0.469443
# 2   0.029016  0.208641  0.469443
# 3   0.147656  0.208641  0.469443
# 4   0.071521  0.208641  0.469443
# 5   0.052523  0.208641  0.469443
# 6   0.042675  0.208641  0.469443
# 7   0.036007  0.208641  0.469443
# 8   0.032069  0.208641  0.469443
# 9   0.029062  0.208641  0.469443
# 10  0.029062  0.208641  0.469443
# 11  0.029062  0.208641  0.469443
# 12  0.029062  0.208641  0.469443
# 13  0.029062  0.208641  0.469443
# 14  0.029062  0.208641  0.469443
# 15  0.031392  0.208641  0.469443
# 16  0.031392  0.208641  0.469443
# 17  0.036049  0.208641  0.469443

# %%
# print(cr)
# print(cr.rc_in.conc_sect_info)
# print(cr.rc_in.reinf_place_info_TYPES12)

cr.plot_section()
# plt.show()

# %%
cr.prepare_AnySection(r'E:\tests\anysection_tets\test_python.txt')
